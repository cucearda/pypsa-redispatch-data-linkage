# %%
from plant_match_pre_filtering import load_redispatch_keys, PowerPlant, RedispatchKey
from datetime import date
import pandas as pd

# %%
redispatch_keys = load_redispatch_keys("redispatch_top100.csv")

# %%
print(len(redispatch_keys), "redispatch keys loaded")
